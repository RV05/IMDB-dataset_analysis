# %% [markdown]
# <a href="https://colab.research.google.com/github/RV05/IMDB-dataset_analysis/blob/main/imdb_guided_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
imbd_df=pd.read_csv("/content/drive/MyDrive/imdb_data.csv")

# %%
imbd_df.head()
# Out:
#    id  ...   revenue
# 0   1  ...  12314651
# 1   2  ...  95149435
# 2   3  ...  13092000
# 3   4  ...  16000000
# 4   5  ...   3923970
#
# [5 rows x 23 columns]

# %%
imbd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imbd_df["crew"]
# Out:
# 0       [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# 1       [{'credit_id': '52fe43fe9251416c7502563d', 'de...
# 2       [{'credit_id': '54d5356ec3a3683ba0000039', 'de...
# 3       [{'credit_id': '52fe48779251416c9108d6eb', 'de...
# 4       [{'credit_id': '52fe464b9251416c75073b43', 'de...
#                               ...
# 2995    [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...
# 2996    [{'credit_id': '5716b72ac3a3686678012c84', 'de...
# 2997    [{'credit_id': '52fe443a9251416c7502d579', 'de...
# 2998    [{'credit_id': '556f817b9251410866000a63', 'de...
# 2999    [{'credit_id': '5391990d0e0a260fb5001629', 'de...
# Name: crew, Length: 3000, dtype: object

# %%
imbd_df["crew"][0]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
type(imbd_df.loc[0,'crew'])
# Out:
# str

# %%
from ast import literal_eval

# %%
literal_eval(imbd_df.loc[0,'crew'])
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
literal_eval(imbd_df.loc[0,'cast'])
# Out:
# [{'cast_id': 4,
#   'character': 'Lou',
#   'credit_id': '52fe4ee7c3a36847f82afae7',
#   'gender': 2,
#   'id': 52997,
#   'name': 'Rob Corddry',
#   'order': 0,
#   'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'},
#  {'cast_id': 5,
#   'character': 'Nick',
#   'credit_id': '52fe4ee7c3a36847f82afaeb',
#   'gender': 2,
#   'id': 64342,
#   'name': 'Craig Robinson',
#   'order': 1,
#   'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#  {'cast_id': 6,
#   'character': 'Jacob',
#   'credit_id': '52fe4ee7c3a36847f82afaef',
#   'gender': 2,
#   'id': 54729,
#   'name': 'Clark Duke',
#   'order': 2,
#   'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'},
#  {'cast_id': 7,
#   'character': 'Adam Jr.',
#   'credit_id': '52fe4ee7c3a36847f82afaf3',
#   'gender': 2,
#   'id': 36801,
#   'name': 'Adam Scott',
#   'order': 3,
#   'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'},
#  {'cast_id': 8,
#   'character': 'Hot Tub Repairman',
#   'credit_id': '52fe4ee7c3a36847f82afaf7',
# ...

# %%
imbd_df[imbd_df["budget"]==0].head()
# Out:
#     id  ...   revenue
# 4    5  ...   3923970
# 7    8  ...   2586511
# 8    9  ...  34327391
# 11  12  ...  22642033
# 17  18  ...   1234254
#
# [5 rows x 23 columns]

# %%
len(imbd_df[imbd_df["budget"]==0])
# Out:
# 812

# %%
imbd_df['profit']=imbd_df['revenue']-imbd_df['budget']

# %%
imbd_df['profit'].max()
# Out:
# 1316249360

# %%
max_profit_movie_df=imbd_df[imbd_df['profit']==1316249360]

# %%
max_profit_movie_df
# Out:
#         id  ...      profit
# 1761  1762  ...  1316249360
#
# [1 rows x 24 columns]

# %%
max_profit_movie_df.loc[1761,'crew']
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
max_profit_movie_df.iloc[0]['crew']
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
crew_list=literal_eval(max_profit_movie_df.iloc[0]['crew'])
crew_list
cast_list=literal_eval(max_profit_movie_df.iloc[0]['cast'])
cast_list
# Out:
# [{'cast_id': 17,
#   'character': 'Dominic Toretto',
#   'credit_id': '5431dfd10e0a265915002c34',
#   'gender': 2,
#   'id': 12835,
#   'name': 'Vin Diesel',
#   'order': 0,
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'cast_id': 19,
#   'character': "Brian O'Conner",
#   'credit_id': '5431dfe4c3a3681143002b98',
#   'gender': 2,
#   'id': 8167,
#   'name': 'Paul Walker',
#   'order': 1,
#   'profile_path': '/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg'},
#  {'cast_id': 18,
#   'character': 'Hobbs',
#   'credit_id': '5431dfdbc3a36831a6004376',
#   'gender': 2,
#   'id': 18918,
#   'name': 'Dwayne Johnson',
#   'order': 2,
#   'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'},
#  {'cast_id': 20,
#   'character': 'Letty',
#   'credit_id': '5431dfeec3a36811ef002c75',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 3,
#   'profile_path': '/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg'},
#  {'cast_id': 28,
#   'character': 'Roman',
# ...

# %%
for elem in crew_list:
  # print(elem)
  # print(elem['job'])
  if elem['job']=='Producer':
    print(elem['name']+' is producer')
  

for elem in crew_list:
  # print(elem)
  # print(elem['job'])
  if elem['job']=='Director':
    print(elem['name']+' is director')
# Out:
# Vin Diesel is producer
# Neal H. Moritz is producer
# Michael Fottrell is producer
# Brandon Birtell is producer
# James Wan is director

# %%
demo=[{'credit_id': '52fe4cc8c3a36847f823e681',
  'department': 'Production',
  'gender': 2,
  'id': 12835,
  'job': 'Producer',
  'name': 'Vin Diesel',
  'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
 {'credit_id': '52fe4cc8c3a36847f823e687',
  'department': 'Production',
  'gender': 2,
  'id': 11874,
  'job': 'Producer',
  'name': 'Neal H. Moritz',
  'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},]

# %%
for element in demo:
  # print(element)
  print(element['name'])
# Out:
# Vin Diesel
# Neal H. Moritz

# %%
crew_df=pd.DataFrame(crew_list)
cast_df=pd.DataFrame(cast_list)
crew_df.head()
# Out:
#                   credit_id  ...                      profile_path
# 0  52fe4cc8c3a36847f823e681  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1  52fe4cc8c3a36847f823e687  ...  /cNcsEYmoS4niCz3UkVAA09dUIob.jpg
# 2  52fe4cc8c3a36847f823e68d  ...  /dUGxIwFBLrSFLImxjeda1krndMO.jpg
# 3  52fe4cc8c3a36847f823e693  ...  /e2dMfqFvRsOXgWZ1VToYLmos17y.jpg
# 4  52fe4cc8c3a36847f823e699  ...  /d1LSKfzi5J6QngWS7niN1zPJdud.jpg
#
# [5 rows x 7 columns]

# %%
crew_df[(crew_df['job']=='Producer')|(crew_df['job']=='Director')]
# Out:
#                    credit_id  ...                      profile_path
# 0   52fe4cc8c3a36847f823e681  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1   52fe4cc8c3a36847f823e687  ...  /cNcsEYmoS4niCz3UkVAA09dUIob.jpg
# 4   52fe4cc8c3a36847f823e699  ...  /d1LSKfzi5J6QngWS7niN1zPJdud.jpg
# 10  554fa7f2c3a3682254004803  ...                              None
# 11  554fa80292514110bd002aa8  ...                              None
#
# [5 rows x 7 columns]

# %%
crew_df[crew_df['job'].isin(['Producer','Director'])]
# Out:
#                    credit_id  ...                      profile_path
# 0   52fe4cc8c3a36847f823e681  ...  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1   52fe4cc8c3a36847f823e687  ...  /cNcsEYmoS4niCz3UkVAA09dUIob.jpg
# 4   52fe4cc8c3a36847f823e699  ...  /d1LSKfzi5J6QngWS7niN1zPJdud.jpg
# 10  554fa7f2c3a3682254004803  ...                              None
# 11  554fa80292514110bd002aa8  ...                              None
#
# [5 rows x 7 columns]

# %%
cast_df.head()
# Out:
#    cast_id        character  ... order                      profile_path
# 0       17  Dominic Toretto  ...     0  /7rwSXluNWZAluYMOEWBxkPmckES.jpg
# 1       19   Brian O'Conner  ...     1  /iqvYezRoEY5k8wnlfHriHQfl5dX.jpg
# 2       18            Hobbs  ...     2  /kuqFzlYMc2IrsOyPznMd1FroeGq.jpg
# 3       20            Letty  ...     3  /v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg
# 4       28            Roman  ...     4  /a3tyF7QXgeEH0QuEuIzNZZ8oLNS.jpg
#
# [5 rows x 8 columns]

# %%
print(max_profit_movie_df.title.iloc[0]+" has the highest profit")
# Out:
# Furious 7 has the highest profit

# %%
crew_df[(crew_df['job']=='Producer')]['name'].tolist()
# Out:
# ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell']

# %%
crew_df[(crew_df['job']=='Director')]['name'].tolist()
# Out:
# ['James Wan']

# %%
median_budget_of_sane_data=imbd_df[imbd_df['budget']>1000000]['budget'].median()

# %%
#imp
imbd_df.loc[imbd_df['budget']<1000000,'budget']=median_budget_of_sane_data

# %%
imbd_df['profit']=imbd_df['revenue']-imbd_df['budget']
imbd_df['roi']=100*imbd_df['profit']/imbd_df['budget']

# %%
imbd_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
# imbd_df.replace({'budget':0},imbd_df[imbd_df['budget']!=0]['budget'].median(),inplace=True)

# %%
imbd_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
imbd_df['roi'].max()
# Out:
# 11623.5147

# %%
imbd_df['original_language'].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
roi_language_df= imbd_df.groupby('original_language')['roi'].mean().reset_index()

# %%
max_roi_lan=roi_language_df[roi_language_df['roi']==roi_language_df['roi'].max()]

# %%
print(max_roi_lan)
# Out:
#    original_language        roi
# 12                he  456.29245

# %%
imbd_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
imbd_df[imbd_df['roi']==849999900.0]
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue, profit, roi]
# Index: []

# %%
len(imbd_df[imbd_df['budget']<1000000])
# Out:
# 0

# %% [markdown]
# #Find out the unique genres of movies in this dataset.

# %%
imbd_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
imbd_df_no_na_genres=imbd_df[~imbd_df['genres'].isna()]

# %%
len(imbd_df_no_na_genres)
# Out:
# 2993

# %%
imbd_df_no_na_genres[imbd_df_no_na_genres['genres'].isna()==True]
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue, profit, roi]
# Index: []

# %%
# imbd_df_no_na_genres['genres_list']=imbd_df_no_na_genres.apply(lambda s:literal_eval(s),axis=1)

# %%
imbd_df.head()
# Out:
#    id                              belongs_to_collection  ...    profit          roi
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  ...  -1685349   -12.038207
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  ...  55149435   137.873588
# 2   3                                                NaN  ...   9792000   296.727273
# 3   4                                                NaN  ...  14800000  1233.333333
# 4   5                                                NaN  ... -15576030   -79.877077
#
# [5 rows x 25 columns]

# %%
no_na=imbd_df[~imbd_df['genres'].isna()]

# %%
no_na[no_na['genres'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [id, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue, profit, roi]
# Index: []

# %%
no_na['genres_list']=no_na['genres'].apply(lambda s:literal_eval(s))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
no_na.head()
# Out:
#    id  ...                                        genres_list
# 0   1  ...                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  ...  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3  ...                      [{'id': 18, 'name': 'Drama'}]
# 3   4  ...  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5  ...  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
# [5 rows x 26 columns]

# %%
genre_list=no_na.loc[1,'genres_list']

# %%
for elem in genre_list:
  print(elem['name'])
# Out:
# Comedy
# Drama
# Family
# Romance

# %%
pd.DataFrame(genre_list)
# Out:
#       id     name
# 0     35   Comedy
# 1     18    Drama
# 2  10751   Family
# 3  10749  Romance

# %%
genres_list=[]
for index,row in no_na.iterrows():
  genre_list=no_na.loc[index,'genres_list']
  for elem in genre_list:
    # genres_list.append(elem['name'])
    print(elem['name'])
# Out:
# Comedy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-0bc5c7f4ba62> in <module>()
#       4   for elem in genre_list:
#       5     # genres_list.append(elem['name'])
# ----> 6     print(elem['name'])
#       7
#
# TypeError: string indices must be integers

# %%
genre_list
# Out:
# [{'id': 35, 'name': 'Comedy'}, 'Comedy', 'Comedy']

# %%
genres_df.drop_duplicates()

# %% [markdown]
# ##Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI
#
#
# ```
# # This is formatted as code
# ```

# %%
imbd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imbd_df_no_na_crew = imbd_df[~imbd_df['crew'].isna()]

# %%
len(imbd_df_no_na_crew)
# Out:
# 2984

# %%
def get_producers_and_directors(string_rep_of_crew_list):
  try:
    crew_list = literal_eval(string_rep_of_crew_list)
    producer_list = []
    director_list = []
    for elem in crew_list:
      if elem['job']=='Producer':
        producer_list.append(elem['name'])
      if elem['job']=='Director':
        director_list.append(elem['name'])
    return producer_list, director_list
  except:
    return [], []

# %%
get_producers_and_directors(imbd_df_no_na_crew.loc[1, 'crew'])
# Out:
# (['Whitney Houston', 'Mario Iscovich', 'Debra Martin Chase'],
#  ['Garry Marshall'])

# %%
imbd_df[['producers', 'directors']] = imbd_df.apply(lambda s: get_producers_and_directors(s['crew']), axis=1, result_type="expand")

# %%
{
    'p1':{'movies':['m1,m2,m3'],'avg_roi':23},'p2':{}
}
# Out:
# {'p1': {'avg_roi': 23, 'movies': ['m1,m2,m3']}, 'p2': {}}

# %%
producer_dict = {}
for index, row in imbd_df.iterrows():
  for producer in row['producers']:
    if producer not in producer_dict.keys():
      # add producer in dict
      producer_dict[producer] = [row['roi']]
    else:
      # update the movie for this producer
      value = producer_dict[producer]
      value.append(row['roi'])
      producer_dict[producer] = value

# %%
pd.DataFrame.from_dict(producer_dict, orient='index').mean(axis=1).reset_index().rename(columns={'index':'producer', 0:'average_roi'}).sort_values('average_roi', ascending=False)
# Out:
#                 producer  average_roi
# 2635       Michael White  9307.693250
# 1526       Gregg Hoffman  8559.305750
# 3205      Nelson Greaves  6188.209000
# 2842    Howard G. Minsky  6100.000000
# 1264      Norman Spencer  5458.946615
# ...                  ...          ...
# 1804     Arthur H. Nadel   -99.999964
# 1805        Lou Scheimer   -99.999964
# 1970          Elia Kazan   -99.999974
# 601    Pushpa Kandaswamy   -99.999985
# 2541  Erich von Stroheim   -99.999995
#
# [3546 rows x 2 columns]
